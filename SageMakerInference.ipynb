# %% [markdown]
# ## Notebook execution in Jupyter for inference

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\xkorpijo3\\OneDrive - Fortum\\Desktop\\Master-thesis-GBRT-dam'

# %%
# !python ./models/HST.py
# Out:
# Split 1: RMSE = 0.8580892051049387
# Split 2: RMSE = 2.240353278419824
# Split 3: RMSE = 1.24305470620932
#
# ~~~ TARGET ~~~
# GV1
#
# ~~~ TEST METRICS ~~~
# RMSE_train: 0.508
# RMSE_crossval: 1.447
# RMSE_test: 0.591
# MAE_test: 0.451
# Nash-Sutcliffe Test: 0.967
# Kling-Gupta Test: 0.896
#
# ~~~ OTHER STATS ~~~
# Train data length: 38 months
# Target inference time: 6.6729 seconds
#
# Split 1: RMSE = 1.217118727562643
# Split 2: RMSE = 3.3511328514470375
# Split 3: RMSE = 2.3950071177193224
#
# ~~~ TARGET ~~~
# GV3
#
# ~~~ TEST METRICS ~~~
# RMSE_train: 0.750
# RMSE_crossval: 2.321
# RMSE_test: 1.039
# MAE_test: 0.822
# Nash-Sutcliffe Test: 0.935
# Kling-Gupta Test: 0.957
#
# ~~~ OTHER STATS ~~~
# Train data length: 38 months
# Target inference time: 4.3561 seconds
#
# Split 1: RMSE = 0.5348024882665503
# Split 2: RMSE = 1.7320672677487672
# Split 3: RMSE = 1.368873504262628
#
# ~~~ TARGET ~~~
# GV51
#
# ~~~ TEST METRICS ~~~
# RMSE_train: 0.501
# RMSE_crossval: 1.212
# ...

# %%
# !python ./models/LightGBM_inference.py
# Out:
# 1th fold: LGBMRegressor RMSE: 0.5111
# 2th fold: LGBMRegressor RMSE: 0.2313
# 3th fold: LGBMRegressor RMSE: 0.1703
#
# ~~~ TARGET ~~~
# GV1
#
# ~~~ MODEL ~~~
# Best parameters: {'n_estimators': 2984, 'learning_rate': 0.018, 'max_depth': 11, 'num_leaves': 4, 'subsample': 0.84, 'feature_fraction': 0.57, 'min_gain_to_split': 6.7, 'reg_alpha': 0.0, 'reg_lambda': 1.56, 'boosting_type': 'gbdt', 'linear_tree': True}
#
# ~~~ TEST METRICS ~~~
# RMSE_train: 0.108
# RMSE_crossval: 0.304
# RMSE_test: 0.326
# MAE_test: 0.236
# Nash-Sutcliffe Test: 0.990
# Kling-Gupta Test: 0.941
#
# ~~~ OTHER STATS ~~~
# Train data length: 38 months
# Target inference time: 5.0220 seconds
#
# 1th fold: LGBMRegressor RMSE: 0.8555
# 2th fold: LGBMRegressor RMSE: 0.2950
# 3th fold: LGBMRegressor RMSE: 1.2872
#
# ~~~ TARGET ~~~
# GV3
#
# ~~~ MODEL ~~~
# ...

# %%
# !python ./models/XGBoost_inference.py
# Out:
# 1th fold: XGBRegressor RMSE: 0.5034
# 2th fold: XGBRegressor RMSE: 0.1798
# 3th fold: XGBRegressor RMSE: 0.8027
#
# ~~~ TARGET ~~~
# GV1
#
# ~~~ MODEL ~~~
# Best parameters: {'n_estimators': 820, 'learning_rate': 0.00901, 'max_depth': 9, 'max_leaves': 6, 'colsample_bytree': 0.68, 'subsample': 0.88, 'reg_alpha': 3.97, 'reg_lambda': 3.34, 'gamma': 4.07}
#
# ~~~ TEST METRICS ~~~
# RMSE_train: 0.099
# RMSE_crossval: 0.495
# RMSE_test: 0.345
# MAE_test: 0.249
# Nash-Sutcliffe Test: 0.989
# Kling-Gupta Test: 0.950
#
# ~~~ OTHER STATS ~~~
# Train data length: 38 months
# Target inference time: 5.8078 seconds
#
# 1th fold: XGBRegressor RMSE: 0.8192
# 2th fold: XGBRegressor RMSE: 0.3499
# 3th fold: XGBRegressor RMSE: 1.3897
#
# ~~~ TARGET ~~~
# GV3
#
# ~~~ MODEL ~~~
# Best parameters: {'n_estimators': 2079, 'learning_rate': 0.00301, 'max_depth': 10, 'max_leaves': 11, 'colsample_bytree': 0.57, 'subsample': 0.64, 'reg_alpha': 8.91, 'reg_lambda': 7.29, 'gamma': 3.99}
#
# ~~~ TEST METRICS ~~~
# ...

# %%
# !python ./models/GBRT_inference.py
# Out:
# 1th fold: HistGradientBoostingRegressor RMSE: 0.4238
# 2th fold: HistGradientBoostingRegressor RMSE: 0.2477
# 3th fold: HistGradientBoostingRegressor RMSE: 0.7366
#
# ~~~ TARGET ~~~
# GV1
#
# ~~~ MODEL ~~~
# Best parameters: {'max_iter': 914, 'learning_rate': 0.066, 'max_depth': 2, 'min_samples_leaf': 22, 'l2_regularization': 8.14, 'max_features': 0.77, 'early_stopping': 'auto'}
#
# ~~~ TEST METRICS ~~~
# RMSE_train: 0.072
# RMSE_crossval: 0.469
# RMSE_test: 0.289
# MAE_test: 0.214
# Nash-Sutcliffe Test: 0.992
# Kling-Gupta Test: 0.959
#
# ~~~ OTHER STATS ~~~
# Train data length: 38 months
# Target inference time: 7.8510 seconds
#
# 1th fold: HistGradientBoostingRegressor RMSE: 0.7650
# 2th fold: HistGradientBoostingRegressor RMSE: 0.3763
# 3th fold: HistGradientBoostingRegressor RMSE: 1.3715
#
# ~~~ TARGET ~~~
# GV3
#
# ~~~ MODEL ~~~
# ...

# %%
print("Inference finished")
# Out:
# Inference finished
